# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('./uncleaned bike sales data.xlsx')
df
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
df.head(30)
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# 5          261700 2021-12-03   3.0  December  2021            24
# 6          261701 2021-12-03   3.0  December  2021            37
# 7          261701 2021-12-03   3.0  December  2021            37
# 8          261702 2021-12-04   4.0  December  2021            31
# 9          261703 2021-12-05   5.0  December  2021            39
# 10         261704 2021-12-05   NaN  December  2021            42
# 11         261705 2021-12-05   5.0  December  2021            35
# 12         261706 2021-12-05   5.0  December  2021            37
# ...

# %%
df[['Customer_Age','Order_Quantity', ' Unit_Cost ',' Unit_Price ', ' Profit ', ' Cost ', 'Revenue']].describe()
# Out:
#        Customer_Age  Order_Quantity   Unit_Cost    Unit_Price       Profit   \
# count     89.000000       88.000000    89.000000     89.000000    89.000000
# mean      34.202247        2.125000  1052.247191   1940.943820  1848.887640
# std        8.090651        1.239322   440.499001    789.955743  1394.401162
# min       17.000000        1.000000     0.000000      0.000000   245.000000
# 25%       30.000000        1.000000   420.000000   2295.000000  1043.000000
# 50%       35.000000        2.000000  1252.000000   2295.000000  1054.000000
# 75%       38.000000        3.000000  1266.000000   2320.000000  2954.000000
# max       63.000000        4.000000  1912.000000   3400.000000  5908.000000
#
#              Cost       Revenue
# count    89.000000     89.00000
# mean   2204.235955   4043.94382
# std    1730.330926   3139.75858
# min       0.000000      0.00000
# 25%    1252.000000   2295.00000
# 50%    1266.000000   2320.00000
# 75%    3756.000000   6750.00000
# ...

# %%
df.isnull().sum()
# Out:
# Sales_Order #          0
# Date                   0
# Day                    1
# Month                  0
# Year                   0
# Customer_Age           0
# Age_Group              1
# Customer_Gender        0
# Country                0
# State                  0
# Product_Category       0
# Sub_Category           0
# Product_Description    1
# Order_Quantity         1
#  Unit_Cost             0
#  Unit_Price            0
#  Profit                0
#  Cost                  0
# Revenue                0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.date
df
# Out:
#     Sales_Order #        Date   Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01   1.0  December  2021            39
# 1          261695  2021-12-01   1.0  December  2021            44
# 2          261697  2021-12-02   2.0  December  2021            37
# 3          261698  2021-12-02   2.0  December  2021            31
# 4          261699  2021-12-03   3.0  December  2021            37
# ..            ...         ...   ...       ...   ...           ...
# 84         261778  2021-12-22  22.0  December  2021            41
# 85         261779  2021-12-23  23.0  December  2021            30
# 86         261780  2021-12-23  23.0  December  2021            31
# 87         261781  2021-12-23  23.0  December  2021            35
# 88         261782  2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
df = df.dropna()

# %%
df['Day'] = df['Day'].apply(lambda x: int(x))
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11688\374986381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day'] = df['Day'].apply(lambda x: int(x))
#     Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01    1  December  2021            39
# 1          261695  2021-12-01    1  December  2021            44
# 2          261697  2021-12-02    2  December  2021            37
# 3          261698  2021-12-02    2  December  2021            31
# 4          261699  2021-12-03    3  December  2021            37
# ..            ...         ...  ...       ...   ...           ...
# 84         261778  2021-12-22   22  December  2021            41
# ...

# %%
df
# Out:
#     Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01    1  December  2021            39
# 1          261695  2021-12-01    1  December  2021            44
# 2          261697  2021-12-02    2  December  2021            37
# 3          261698  2021-12-02    2  December  2021            31
# 4          261699  2021-12-03    3  December  2021            37
# ..            ...         ...  ...       ...   ...           ...
# 84         261778  2021-12-22   22  December  2021            41
# 85         261779  2021-12-23   23  December  2021            30
# 86         261780  2021-12-23   23  December  2021            31
# 87         261781  2021-12-23   23  December  2021            35
# 88         261782  2021-12-24   24  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
df[' Unit_Price '] = df[' Unit_Price '].apply(lambda x: float(x))
df[' Unit_Cost '] = df[' Unit_Cost '].apply(lambda x: float(x))
df[' Profit '] = df[' Profit '].apply(lambda x: float(x))
df[' Cost '] = df[' Cost '].apply(lambda x: float(x))
df['Revenue'] = df['Revenue'].apply(lambda x: float(x))
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11688\2080833660.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[' Unit_Price '] = df[' Unit_Price '].apply(lambda x: float(x))
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11688\2080833660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[' Unit_Cost '] = df[' Unit_Cost '].apply(lambda x: float(x))
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11688\2080833660.py:3: SettingWithCopyWarning:
# ...

# %%
df[['Customer_Age','Order_Quantity', ' Unit_Cost ',' Unit_Price ', ' Profit ', ' Cost ', 'Revenue']].describe()
# Out:
#        Customer_Age  Order_Quantity   Unit_Cost    Unit_Price       Profit   \
# count     85.000000       85.000000    85.000000     85.000000    85.000000
# mean      34.023529        2.117647  1054.105882   1944.929412  1847.117647
# std        8.215804        1.238391   441.615595    791.130788  1390.563242
# min       17.000000        1.000000     0.000000      0.000000   245.000000
# 25%       29.000000        1.000000   420.000000   2295.000000  1043.000000
# 50%       35.000000        2.000000  1252.000000   2295.000000  1054.000000
# 75%       38.000000        3.000000  1266.000000   2320.000000  2954.000000
# max       63.000000        4.000000  1912.000000   3400.000000  5908.000000
#
#              Cost        Revenue
# count    85.000000     85.000000
# mean   2204.858824   4045.247059
# std    1724.334158   3127.112059
# min       0.000000      0.000000
# 25%    1252.000000   2295.000000
# 50%    1266.000000   2320.000000
# 75%    3756.000000   6750.000000
# ...

# %%
df[['Customer_Age','Order_Quantity', ' Unit_Cost ',' Unit_Price ', ' Profit ', ' Cost ', 'Revenue']].corr()
# Out:
#                 Customer_Age  Order_Quantity   Unit_Cost    Unit_Price   \
# Customer_Age        1.000000       -0.028357     0.247716      0.270515
# Order_Quantity     -0.028357        1.000000    -0.050634     -0.075838
#  Unit_Cost          0.247716       -0.050634     1.000000      0.945523
#  Unit_Price         0.270515       -0.075838     0.945523      1.000000
#  Profit             0.171849        0.750456     0.515364      0.527160
#  Cost               0.159676        0.737892     0.558112      0.519592
# Revenue             0.172229        0.721892     0.530983      0.553934
#
#                  Profit      Cost    Revenue
# Customer_Age    0.171849  0.159676  0.172229
# Order_Quantity  0.750456  0.737892  0.721892
#  Unit_Cost      0.515364  0.558112  0.530983
#  Unit_Price     0.527160  0.519592  0.553934
#  Profit         1.000000  0.986391  0.994026
#  Cost           0.986391  1.000000  0.981418
# Revenue         0.994026  0.981418  1.000000

# %%
df['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults (35-64)          44
# Young Adults (25-34)    31
# Youth (<25)             10
# Name: count, dtype: int64

# %%
df['Age_Group'] = ''  # Initialize the 'Age_Group' column

for i, x in df['Customer_Age'].items():
    if x < 25:
        df.loc[i, 'Age_Group'] = 'Youth'
    elif x >= 25 and x <= 34:
        df.loc[i, 'Age_Group'] = 'Young Adults'
    elif x >= 35 and x <= 64:
        df.loc[i, 'Age_Group'] = 'Adults'
    else:
        df.loc[i, 'Age_Group'] = 'Seniors'
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11688\1424964636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_Group'] = ''  # Initialize the 'Age_Group' column

# %%
df.tail(50)
# Out:
#     Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 39         261733  2021-12-12   12  December  2021            35
# 40         261734  2021-12-12   12  December  2021            38
# 41         261735  2021-12-13   13  December  2021            32
# 42         261736  2021-12-13   13  December  2021            40
# 43         261737  2021-12-13   13  December  2021            44
# 44         261738  2021-12-13   13  December  2021            49
# 45         261739  2021-12-14   14  December  2021            30
# 46         261740  2021-12-14   14  December  2021            32
# 47         261741  2021-12-14   14  December  2021            32
# 48         261742  2021-12-15   15  December  2021            29
# 49         261743  2021-12-16   16  December  2021            33
# 50         261744  2021-12-16   16  December  2021            38
# 51         261745  2021-12-16   16  December  2021            27
# ...

# %%
df['Product_Description'].value_counts()
# Out:
# Product_Description
# Mountain-200 Black, 46       15
# Mountain-200 Silver, 38      14
# Mountain-200 Black, 38       12
# Mountain-200 Silver, 42       9
# Mountain-200 Black, 42        6
# Mountain-400-W Silver, 46     6
# Mountain-400-W Silver, 42     4
# Mountain-200 Silver, 46       4
# Mountain-500 Silver, 42       3
# Mountain-400-W Silver, 38     2
# Mountain-100 Black, 38        2
# Mountain-500 Black, 40        2
# Mountain-100 Silver, 44       1
# Mountain-500 Silver, 40       1
# Mountain-500 Black, 44        1
# Mountain-100 Black, 48        1
# Mountain-500 Black, 52        1
# Mountain-500 Black, 42        1
# Name: count, dtype: int64

# %%
df[['Product_Description','Size']] = df['Product_Description'].str.split(' ,', n=2, expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df[['Product_Description','Color','Size']] = df['Product_Description'].str.split(' ,', n=2, expand=True)
#
# File ~\anaconda3\envs\Vision\lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\envs\Vision\lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# ...

# %%
df
# Out:
#     Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01    1  December  2021            39
# 1          261695  2021-12-01    1  December  2021            44
# 2          261697  2021-12-02    2  December  2021            37
# 3          261698  2021-12-02    2  December  2021            31
# 4          261699  2021-12-03    3  December  2021            37
# ..            ...         ...  ...       ...   ...           ...
# 84         261778  2021-12-22   22  December  2021            41
# 85         261779  2021-12-23   23  December  2021            30
# 86         261780  2021-12-23   23  December  2021            31
# 87         261781  2021-12-23   23  December  2021            35
# 88         261782  2021-12-24   24  December  2021            38
#
#        Age_Group Customer_Gender         Country             State  \
# 0         Adults               F   United States        California
# ...

# %%
df[['Product_Description','Color']] = df['Product_Description'].str.split(' ', n=1, expand=True)

# %%
df
# Out:
#     Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01    1  December  2021            39
# 1          261695  2021-12-01    1  December  2021            44
# 2          261697  2021-12-02    2  December  2021            37
# 3          261698  2021-12-02    2  December  2021            31
# 4          261699  2021-12-03    3  December  2021            37
# ..            ...         ...  ...       ...   ...           ...
# 84         261778  2021-12-22   22  December  2021            41
# 85         261779  2021-12-23   23  December  2021            30
# 86         261780  2021-12-23   23  December  2021            31
# 87         261781  2021-12-23   23  December  2021            35
# 88         261782  2021-12-24   24  December  2021            38
#
#        Age_Group Customer_Gender         Country             State  ...  \
# 0         Adults               F   United States        California  ...
# ...

# %%
df.columns
# Out:
# Index(['Sales_Order #', 'Date', 'Day', 'Month', 'Year', 'Customer_Age',
#        'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product_Description', 'Size', 'Order_Quantity',
#        ' Unit_Cost ', ' Unit_Price ', ' Profit ', ' Cost ', 'Revenue',
#        'Color'],
#       dtype='object')

# %%
df = df[['Sales_Order #', 'Date', 'Day', 'Month', 'Year', 'Customer_Age',
       'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category',
       'Sub_Category', 'Product_Description','Size','Color', 'Order_Quantity', ' Unit_Cost ',
       ' Unit_Price ', ' Profit ', ' Cost ', 'Revenue']]

# %%
df
# Out:
#     Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01    1  December  2021            39
# 1          261695  2021-12-01    1  December  2021            44
# 2          261697  2021-12-02    2  December  2021            37
# 3          261698  2021-12-02    2  December  2021            31
# 4          261699  2021-12-03    3  December  2021            37
# ..            ...         ...  ...       ...   ...           ...
# 84         261778  2021-12-22   22  December  2021            41
# 85         261779  2021-12-23   23  December  2021            30
# 86         261780  2021-12-23   23  December  2021            31
# 87         261781  2021-12-23   23  December  2021            35
# 88         261782  2021-12-24   24  December  2021            38
#
#        Age_Group Customer_Gender         Country             State  ...  \
# 0         Adults               F   United States        California  ...
# ...

# %%
df.to_csv('./bike_sales_data.csv')
