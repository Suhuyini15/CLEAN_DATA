# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./ethereum.csv')
df
# Out:
#        Blockno  UnixTimestamp       DateTime (UTC)  Value_IN(ETH)  \
# 0     19557289     1711929611  2024-04-01 00:00:11          0.000
# 1     19557290     1711929623  2024-04-01 00:00:23          0.000
# 2     19557290     1711929623  2024-04-01 00:00:23          0.000
# 3     19557291     1711929635  2024-04-01 00:00:35          0.000
# 4     19557291     1711929635  2024-04-01 00:00:35          0.000
# ...        ...            ...                  ...            ...
# 4995  19560943     1711974095  2024-04-01 12:21:35          0.800
# 4996  19560945     1711974119  2024-04-01 12:21:59          0.000
# 4997  19560945     1711974119  2024-04-01 12:21:59          0.000
# 4998  19560946     1711974131  2024-04-01 12:22:11          0.000
# 4999  19560946     1711974131  2024-04-01 12:22:11          0.559
#
#       Value_OUT(ETH)  CurrentValue @ $3083.38454496098/Eth  TxnFee(ETH)  \
# 0                  0                              0.000000     0.002915
# ...

# %%
df.head(30)
# Out:
#      Blockno  UnixTimestamp       DateTime (UTC)  Value_IN(ETH)  \
# 0   19557289     1711929611  2024-04-01 00:00:11       0.000000
# 1   19557290     1711929623  2024-04-01 00:00:23       0.000000
# 2   19557290     1711929623  2024-04-01 00:00:23       0.000000
# 3   19557291     1711929635  2024-04-01 00:00:35       0.000000
# 4   19557291     1711929635  2024-04-01 00:00:35       0.000000
# 5   19557294     1711929671  2024-04-01 00:01:11       0.000000
# 6   19557294     1711929671  2024-04-01 00:01:11       0.000000
# 7   19557294     1711929671  2024-04-01 00:01:11       0.000000
# 8   19557296     1711929695  2024-04-01 00:01:35       0.500000
# 9   19557298     1711929719  2024-04-01 00:01:59       0.000000
# 10  19557299     1711929731  2024-04-01 00:02:11       0.000000
# 11  19557299     1711929731  2024-04-01 00:02:11       0.000000
# 12  19557301     1711929755  2024-04-01 00:02:35       0.000000
# 13  19557302     1711929767  2024-04-01 00:02:47       0.195781
# ...

# %%
df.isnull().sum()
# Out:
# Blockno                                 0
# UnixTimestamp                           0
# DateTime (UTC)                          0
# Value_IN(ETH)                           0
# Value_OUT(ETH)                          0
# CurrentValue @ $3083.38454496098/Eth    0
# TxnFee(ETH)                             0
# TxnFee(USD)                             0
# Historical $Price/Eth                   0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df['DateTime (UTC)'] = pd.to_datetime(df['DateTime (UTC)'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11088\2299167997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DateTime (UTC)'] = pd.to_datetime(df['DateTime (UTC)'])

# %%
df['Date'] = df['DateTime (UTC)'].dt.date
df['Time(UTC)'] = df['DateTime (UTC)'].dt.time
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11088\47737546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['DateTime (UTC)'].dt.date
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11088\47737546.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time(UTC)'] = df['DateTime (UTC)'].dt.time
#        Blockno  UnixTimestamp      DateTime (UTC)  Value_IN(ETH)  \
# 0     19557289     1711929611 2024-04-01 00:00:11          0.000
# ...

# %%
df['UnixTimestamp'] = pd.to_datetime(df['UnixTimestamp'],unit='ms')
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11088\304664404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['UnixTimestamp'] = pd.to_datetime(df['UnixTimestamp'],unit='ms')
#        Blockno           UnixTimestamp      DateTime (UTC)  Value_IN(ETH)  \
# 0     19557289 1970-01-20 19:32:09.611 2024-04-01 00:00:11          0.000
# 1     19557290 1970-01-20 19:32:09.623 2024-04-01 00:00:23          0.000
# 2     19557290 1970-01-20 19:32:09.623 2024-04-01 00:00:23          0.000
# 3     19557291 1970-01-20 19:32:09.635 2024-04-01 00:00:35          0.000
# 4     19557291 1970-01-20 19:32:09.635 2024-04-01 00:00:35          0.000
# ...        ...                     ...                 ...            ...
# ...

# %%
df = df.drop(columns='DateTime (UTC)')
df
# Out:
#        Blockno           UnixTimestamp  Value_IN(ETH)  Value_OUT(ETH)  \
# 0     19557289 1970-01-20 19:32:09.611          0.000               0
# 1     19557290 1970-01-20 19:32:09.623          0.000               0
# 2     19557290 1970-01-20 19:32:09.623          0.000               0
# 3     19557291 1970-01-20 19:32:09.635          0.000               0
# 4     19557291 1970-01-20 19:32:09.635          0.000               0
# ...        ...                     ...            ...             ...
# 4995  19560943 1970-01-20 19:32:54.095          0.800               0
# 4996  19560945 1970-01-20 19:32:54.119          0.000               0
# 4997  19560945 1970-01-20 19:32:54.119          0.000               0
# 4998  19560946 1970-01-20 19:32:54.131          0.000               0
# 4999  19560946 1970-01-20 19:32:54.131          0.559               0
#
#       CurrentValue @ $3083.38454496098/Eth  TxnFee(ETH)  TxnFee(USD)  \
# ...

# %%
df
# Out:
#        Blockno           UnixTimestamp  Value_IN(ETH)  Value_OUT(ETH)  \
# 0     19557289 1970-01-20 19:32:09.611          0.000               0
# 1     19557290 1970-01-20 19:32:09.623          0.000               0
# 2     19557290 1970-01-20 19:32:09.623          0.000               0
# 3     19557291 1970-01-20 19:32:09.635          0.000               0
# 4     19557291 1970-01-20 19:32:09.635          0.000               0
# ...        ...                     ...            ...             ...
# 4995  19560943 1970-01-20 19:32:54.095          0.800               0
# 4996  19560945 1970-01-20 19:32:54.119          0.000               0
# 4997  19560945 1970-01-20 19:32:54.119          0.000               0
# 4998  19560946 1970-01-20 19:32:54.131          0.000               0
# 4999  19560946 1970-01-20 19:32:54.131          0.559               0
#
#       CurrentValue @ $3083.38454496098/Eth  TxnFee(ETH)  TxnFee(USD)  \
# ...

# %%
df['VALUE_IN(USD)'] = (df['Value_IN(ETH)']*df['Historical $Price/Eth'])
df
# Out:
#        Blockno           UnixTimestamp  Value_IN(ETH)  Value_OUT(ETH)  \
# 0     19557289 1970-01-20 19:32:09.611          0.000               0
# 1     19557290 1970-01-20 19:32:09.623          0.000               0
# 2     19557290 1970-01-20 19:32:09.623          0.000               0
# 3     19557291 1970-01-20 19:32:09.635          0.000               0
# 4     19557291 1970-01-20 19:32:09.635          0.000               0
# ...        ...                     ...            ...             ...
# 4995  19560943 1970-01-20 19:32:54.095          0.800               0
# 4996  19560945 1970-01-20 19:32:54.119          0.000               0
# 4997  19560945 1970-01-20 19:32:54.119          0.000               0
# 4998  19560946 1970-01-20 19:32:54.131          0.000               0
# 4999  19560946 1970-01-20 19:32:54.131          0.559               0
#
#       CurrentValue @ $3083.38454496098/Eth  TxnFee(ETH)  TxnFee(USD)  \
# ...

# %%
df['VALUE_OUT(USD)'] = (df['Value_OUT(ETH)']*df['Historical $Price/Eth'])
df
# Out:
#        Blockno           UnixTimestamp  Value_IN(ETH)  Value_OUT(ETH)  \
# 0     19557289 1970-01-20 19:32:09.611          0.000               0
# 1     19557290 1970-01-20 19:32:09.623          0.000               0
# 2     19557290 1970-01-20 19:32:09.623          0.000               0
# 3     19557291 1970-01-20 19:32:09.635          0.000               0
# 4     19557291 1970-01-20 19:32:09.635          0.000               0
# ...        ...                     ...            ...             ...
# 4995  19560943 1970-01-20 19:32:54.095          0.800               0
# 4996  19560945 1970-01-20 19:32:54.119          0.000               0
# 4997  19560945 1970-01-20 19:32:54.119          0.000               0
# 4998  19560946 1970-01-20 19:32:54.131          0.000               0
# 4999  19560946 1970-01-20 19:32:54.131          0.559               0
#
#       CurrentValue @ $3083.38454496098/Eth  TxnFee(ETH)  TxnFee(USD)  \
# ...

# %%
stats_summary = df[['Value_IN(ETH)', 'Value_OUT(ETH)', 'TxnFee(ETH)', 'TxnFee(USD)', 'Historical $Price/Eth']].describe()

# %%
stats_summary
# Out:
#        Value_IN(ETH)  Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  \
# count    4901.000000          4901.0  4901.000000  4901.000000
# mean        0.292032             0.0     0.004028    12.418689
# std         1.321583             0.0     0.014292    44.067512
# min         0.000000             0.0     0.000348     1.072094
# 25%         0.000000             0.0     0.002169     6.687391
# 50%         0.000000             0.0     0.002792     8.608412
# 75%         0.153000             0.0     0.003839    11.838312
# max        50.000000             0.0     0.873585  2693.598488
#
#        Historical $Price/Eth
# count           4.901000e+03
# mean            3.505520e+03
# std             9.095875e-13
# min             3.505520e+03
# 25%             3.505520e+03
# 50%             3.505520e+03
# 75%             3.505520e+03
# max             3.505520e+03

# %%
correlation = df[['Value_IN(ETH)', 'Value_OUT(ETH)', 'TxnFee(ETH)', 'TxnFee(USD)', 'Historical $Price/Eth']].corr()
correlation
# Out:
#                        Value_IN(ETH)  Value_OUT(ETH)  TxnFee(ETH)  \
# Value_IN(ETH)               1.000000             NaN     0.145168
# Value_OUT(ETH)                   NaN             NaN          NaN
# TxnFee(ETH)                 0.145168             NaN     1.000000
# TxnFee(USD)                 0.145168             NaN     1.000000
# Historical $Price/Eth            NaN             NaN          NaN
#
#                        TxnFee(USD)  Historical $Price/Eth
# Value_IN(ETH)             0.145168                    NaN
# Value_OUT(ETH)                 NaN                    NaN
# TxnFee(ETH)               1.000000                    NaN
# TxnFee(USD)               1.000000                    NaN
# Historical $Price/Eth          NaN                    NaN

# %%
df = df.to_csv('./ethereum_new.csv')
